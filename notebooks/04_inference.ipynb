# %% [markdown]
# Gespeichertes Modell laden

# %%
import pickle

with open("../models/rf_pipeline.pkl", "rb") as f:
    model = pickle.load(f)

# %% [markdown]
# prediction test data

# %%
y_pred = model.predict(X_test)
y_proba = model.predict_proba(X_test)[:, 1]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 y_pred = model.predict(X_test)
#       2 y_proba = model.predict_proba(X_test)[:, 1]
#
# NameError: name 'X_test' is not defined

# %%
import pandas as pd
import numpy as np   # <-- WICHTIG!

new_song = pd.DataFrame([{
    "rank": 85,
    "streams": 123456,
    "log_streams": np.log1p(123456),
    "days_on_chart": 3,
    "trend_num": 1,
    "prev_rank": 95,
    "rank_change": 10
}])

new_song
# Out:
#    rank  streams  log_streams  days_on_chart  trend_num  prev_rank  \
# 0    85   123456    11.723648              3          1         95
#
#    rank_change
# 0           10

# %%
prediction = model.predict(new_song)[0]
probability = model.predict_proba(new_song)[:, 1][0]
